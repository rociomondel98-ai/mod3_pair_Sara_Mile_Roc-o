# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("files/world_data_full_apply_nulos.csv", index_col=0)

# %% [markdown]
# # 1. Resumen básico de indicadores clave

# %%
# Calcula, para cada una de estas variables:
df_variables = df[['population', 'density', 'life_expectancy', 'fertility_rate', 'gdp']].agg(["mean", "median", "std", "min", "max"])
df_variables
# Out:
#         population     density  life_expectancy  fertility_rate           gdp
# mean    333.542718  134.504533        72.279679        2.698138  4.772959e+11
# median  215.056000   83.000000        73.200000        2.245000  3.438723e+10
# std     296.467504  157.306774         7.483661        1.282267  2.172173e+12
# min      10.084000    1.265000        52.800000        0.980000  4.727146e+07
# max     973.560000  847.000000        85.400000        6.910000  2.142770e+13

# %%
# Para cada variable - muestra un histograma:
sns.histplot(data=df, x="life_expectancy");

# %%
sns.histplot(data=df, x="fertility_rate");

# %% [markdown]
# # 2. Distribución y forma: esperanza de vida vs. fertilidad

# %%
#Calcula la media y la mediana.
df_2 = df[['life_expectancy', 'fertility_rate']].agg(["mean", "median"])

# %%
df_2
# Out:
#         life_expectancy  fertility_rate
# mean          72.279679        2.698138
# median        73.200000        2.245000

# %%
sns.histplot(data=df, x="life_expectancy")
plt.axvline(df["life_expectancy"].mean(), color="red")
plt.axvline(df["life_expectancy"].median(), color="green");

# %%
sns.histplot(data=df, x="fertility_rate")
plt.axvline(df["fertility_rate"].mean(), color="red")
plt.axvline(df["fertility_rate"].median(), color="green");

# %%
sns.boxplot(data=df, x="life_expectancy")
plt.axvline(df["life_expectancy"].mean(), color="red")
plt.axvline(df["life_expectancy"].median(), color="green");

# %%
sns.boxplot(data=df, x="fertility_rate")
plt.axvline(df["fertility_rate"].mean(), color="red")
plt.axvline(df["fertility_rate"].median(), color="green");

# %% [markdown]
# # 3. Población total vs. densidad de población

# %%
# Calcula para ambas:
df_3 = df[['population', 'density']].agg(["mean", "median", "std"])
df_3
# Out:
#         population     density
# mean    333.542718  134.504533
# median  215.056000   83.000000
# std     296.467504  157.306774

# %%
sns.histplot(data=df, x='population')
plt.axvline(df['population'].mean(), color="red")
plt.axvline(df['population'].median(), color="green")
plt.axvline(df['population'].std(), color="blue");
