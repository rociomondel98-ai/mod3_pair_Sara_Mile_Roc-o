# %%
import pandas as pd
import numpy as np

# %%
df_parte1=pd.read_csv('Files/world-data-2023_part1.csv',index_col=0)

# %%
df_parte2=pd.read_csv('Files/world-data-2023_part2.csv',index_col=0)

# %%
df_parte1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    str
#  1   Density
# (P/Km2)        195 non-null    str
#  2   Abbreviation           188 non-null    str
#  3   Agricultural Land( %)  188 non-null    str
#  4   Land Area(Km2)         194 non-null    str
#  5   Armed Forces size      171 non-null    str
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    str
#  9   Co2-Emissions          188 non-null    str
#  10  CPI                    178 non-null    str
#  11  CPI Change (%)         179 non-null    str
#  12  Currency-Code          180 non-null    str
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    str
# ...

# %%
pd.Series(df_parte1.columns)
# Out:
# 0                   Country
# 1          Density\n(P/Km2)
# 2              Abbreviation
# 3     Agricultural Land( %)
# 4            Land Area(Km2)
# 5         Armed Forces size
# 6                Birth Rate
# 7              Calling Code
# 8        Capital/Major City
# 9             Co2-Emissions
# 10                      CPI
# 11           CPI Change (%)
# 12            Currency-Code
# 13           Fertility Rate
# 14        Forested Area (%)
# 15           Gasoline Price
# dtype: str

# %%
pd.Series(df_parte2.columns)
# Out:
# 0                                           GDP
# 1        Gross primary education enrollment (%)
# 2       Gross tertiary education enrollment (%)
# 3                              Infant mortality
# 4                                  Largest city
# 5                               Life expectancy
# 6                      Maternal mortality ratio
# 7                                  Minimum wage
# 8                             Official language
# 9              Out of pocket health expenditure
# 10                      Physicians per thousand
# 11                                   Population
# 12    Population: Labor force participation (%)
# 13                              Tax revenue (%)
# 14                               Total tax rate
# 15                            Unemployment rate
# 16                             Urban_population
# 17                                      country
# 18                                  coordinates
# dtype: str

# %%
# parte 1 lleva columna de country en indice 0 por lo que da 15 columnas y parte 2 es lo mismo pero sin 
#columna de country por lo que el numero de columnas es 14

# %%
parte3_merge=df_parte1.merge(df_parte2,how='cross',on=None,left_on=None,right_on=None)
parte3_merge.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1  Afghanistan               60           AF                58.10%
# 2  Afghanistan               60           AF                58.10%
# 3  Afghanistan               60           AF                58.10%
# 4  Afghanistan               60           AF                58.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1        652,230           323,000       32.49          93.0
# 2        652,230           323,000       32.49          93.0
# 3        652,230           323,000       32.49          93.0
# 4        652,230           323,000       32.49          93.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# ...

# %%
#4
#Usamos un merge cross

# %% [markdown]
# EJERCICIOS DE LIMPIEZA
#
# 1.Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.

# %% [markdown]
# EJERCICIO 2
#
# Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
#
# No tengan espacios.
#
# Estén en minúscula.
#
# No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
#
# Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
#
# Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.

# %%
pd.Series(parte3_merge.columns)
# Out:
# 0                                       Country
# 1                              Density\n(P/Km2)
# 2                                  Abbreviation
# 3                         Agricultural Land( %)
# 4                                Land Area(Km2)
# 5                             Armed Forces size
# 6                                    Birth Rate
# 7                                  Calling Code
# 8                            Capital/Major City
# 9                                 Co2-Emissions
# 10                                          CPI
# 11                               CPI Change (%)
# 12                                Currency-Code
# 13                               Fertility Rate
# 14                            Forested Area (%)
# 15                               Gasoline Price
# 16                                          GDP
# 17       Gross primary education enrollment (%)
# 18      Gross tertiary education enrollment (%)
# 19                             Infant mortality
# ...

# %%
#vemos que hay dos columnas casi iguales Country y country
print(parte3_merge[['country', 'Country']].head())
# Out:
#        country      Country
# 0  Afghanistan  Afghanistan
# 1      Albania  Afghanistan
# 2      Algeria  Afghanistan
# 3      Andorra  Afghanistan
# 4       Angola  Afghanistan

# %%
parte3_merge.shape
# Out:
# (38025, 35)

# %%
parte3_merge = parte3_merge.drop(columns=['Country'])

# %%
parte3_merge.shape
# Out:
# (38025, 34)

# %%
parte3_merge.columns
# Out:
# Index(['Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'country',
#        'coordinates'],
#       dtype='str')

# %%
parte3_merge = parte3_merge.rename(columns={
    'Density\n(P/Km2)': 'density',
    'Density\r\n(P/Km2)': 'density_2'   # o el nombre que quieras
})
# Out:
#   Cell In[49], line 1
#     parte3_merge={'Density\n(P/Km2)':'density'.lower().replace('Density\n(P/Km2)','density') for 'Density\n(P/Km2)' in 'density'}
#                                                                                                  ^
# SyntaxError: cannot assign to literal
